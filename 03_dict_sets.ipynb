# %%
# sets

# creating sets

nums = {10, 20, 30, 40, 50}

nums
# Out:
# {10, 20, 30, 40, 50}

# %%
type(nums)
# Out:
# set

# %%
nums.add(60)
nums
# Out:
# {10, 20, 30, 40, 50, 60}

# %%
nums.remove(60)
nums
# Out:
# {10, 20, 30, 40, 50}

# %%
# checking existances

print(2 in nums)
# Out:
# False

# %%
print(50 in nums)
# Out:
# True

# %%
# Dictioneries 

user = {
    "name" : "Shailesh",
    "city" : "Mumbai",
    "role" : "Data Scientist"
}

# %%
user
# Out:
# {'name': 'Shailesh', 'city': 'Mumbai', 'role': 'Data Scientist'}

# %%
user["name"]
# Out:
# 'Shailesh'

# %%
user.get("city")
# Out:
# 'Mumbai'

# %%
# add new key 

user["Experience"] = "5  years"

user
# Out:
# {'name': 'Shailesh',
#  'city': 'Mumbai',
#  'role': 'Data Scientist',
#  'Experience': '5  years'}

# %%
# update value 

user["role"] = "ML Engineer"

user
# Out:
# {'name': 'Shailesh',
#  'city': 'Mumbai',
#  'role': 'ML Engineer',
#  'Experience': '5  years'}

# %%
for key , value in user.items():
    print(key , ":", value)
# Out:
# name : Shailesh
# city : Mumbai
# role : ML Engineer
# Experience : 5  years
